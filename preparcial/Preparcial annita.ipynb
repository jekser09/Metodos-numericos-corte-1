# %% [markdown]
# # Preparcial
# ## Anna María Sanchez Rojas
#
#
# Escriba un programa que pregunte al usuario un día de la semana y una hora del día entre las **6** y las **22 hrs** y muestre la actividad que tiene ese día basado en la siguiente tabla, en los espacios vacíos deberá
# mostrar: "libre", además, el programa deberá discriminar los datos, si son numéricos y letras para el día y la hora; el día de la semana debe ser el nombre completo o bien: Lunes =>L, Martes =>M, Miércoles=>Mc, Jueves =>J, Viernes =>V.

# %%
import numpy as np
matriz = np.array([[6,7,"Gym","Gym","Libre","Gym","Gym"],
                   [8,9,"Reunion","Cita medica","Reunion","Libre","Libre"],
                   [10,11,"Asesoria","Libre","Libre","Fondo de inversion","Comite cuantico"],
                   [12,13,"Almuerzo","Almuerzo","Almuerzo","Almuerzo","Almuerzo"],
                   [14,15,"Consultoria","Libre","Ventas y suministros","Gestion de calidad","Libre"],
                   [16,17,"Tutorias","Libre","Libre","Reunion talento humano","Libre"],
                   [18,19,"Matematicas II","Metodos numericos","Matematicas II","Metodos numericos","Tesis"],
                   [20,21,"Sistemas dinamicos","Inteligencia artificial","Sistemas dinamicas","Inteligencia artificial","Farra"]])

print("Tabla: \n",matriz)
# Out:
# Tabla:
#  [['6' '7' 'Gym' 'Gym' 'Libre' 'Gym' 'Gym']
#  ['8' '9' 'Reunion' 'Cita medica' 'Reunion' 'Libre' 'Libre']
#  ['10' '11' 'Asesoria' 'Libre' 'Libre' 'Fondo de inversion'
#   'Comite cuantico']
#  ['12' '13' 'Almuerzo' 'Almuerzo' 'Almuerzo' 'Almuerzo' 'Almuerzo']
#  ['14' '15' 'Consultoria' 'Libre' 'Ventas y suministros'
#   'Gestion de calidad' 'Libre']
#  ['16' '17' 'Tutorias' 'Libre' 'Libre' 'Reunion talento humano' 'Libre']
#  ['18' '19' 'Matematicas II' 'Metodos numericos' 'Matematicas II'
#   'Metodos numericos' 'Tesis']
#  ['20' '21' 'Sistemas dinamicos' 'Inteligencia artificial'
#   'Sistemas dinamicas' 'Inteligencia artificial' 'Farra']]

# %%
bandera=False
while bandera==False:
  dia = str.capitalize(input("Ingrese un dia de Lunes a Viernes: "))
  hora = input("Ingrese una hora entre las 6 y las 22: ")

  if dia.isalpha() and hora.isnumeric():
    validar=int(hora)
    if validar>5 and validar<22:
      
      ###Lunes
      if dia == "Lunes":
        i=0
        j=2
        for fila in range(len(matriz[0])+1):
          columna=0
          for columna in range(len(matriz[:2])):
            if hora == matriz[fila][columna]:
              i=fila
              print("El lunes a las ",hora,"esta en ",matriz[i,j])
              bandera=True
            columna=columna+1
        
      ##Martes
      elif dia == "Martes":
        i=0
        j=3
        for fila in range(len(matriz[0])+1):
          columna=0
          for columna in range(len(matriz[:2])):
            if hora == matriz[fila][columna]:
              i=fila
              print("El martes a las ",hora,"esta en ",matriz[i,j])
              bandera=True
            columna=columna+1
        

      ##Miercoles
      elif dia == "Miercoles":
        i=0
        j=4
        for fila in range(len(matriz[0])+1):
          columna=0
          for columna in range(len(matriz[:2])):
            if hora == matriz[fila][columna]:
              i=fila
              print("El miercoles a las ",hora,"esta en ",matriz[i,j])
              bandera=True
            columna=columna+1
        
      ##Jueves
      elif dia == "Jueves":
        i=0
        j=5
        for fila in range(len(matriz[0])+1):
          columna=0
          for columna in range(len(matriz[:2])):
            if hora == matriz[fila][columna]:
              i=fila
              print("El jueves a las ",hora,"esta en ",matriz[i,j])
              bandera=True
            columna=columna+1

      ##Viernes
      elif dia == "Viernes":
        i=0
        j=6
        for fila in range(len(matriz[0])+1):
          columna=0
          for columna in range(len(matriz[:2])):
            if hora == matriz[fila][columna]:
              i=fila
              print("El viernes a las ",hora,"esta en ",matriz[i,j])
              bandera=True
            columna=columna+1
      else:
        print("Ingrese solo dias de lunes a viernes")
        bandera=False
    else:
      print("Por favor ingrese una hora valida.")
      bandera=False
  else:
    print("Ingrese solo valores validos.")
    bandera=False
# Out:
# Ingrese un dia de Lunes a Viernes: lunes
# Ingrese una hora entre las 6 y las 22: 21
# El lunes a las  21 esta en  Sistemas dinamicos
